# %%
#import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telecom_data=pd.read_csv("E:\\10xAccademy_Practice\\Week 1\\Data\\Week1_challenge_data_source(CSV).csv")
telecom_data.head(10)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5  1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6  1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7  1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8  1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9  1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# ...

# %%
df=telecom_data.copy()

# %%
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %% [markdown]
# After loading the dataset, use different techniques to know or understand the data mor. we can know the attributes
# the data contans, the number of missing and duplicate values in the data, generate statistical summary of the data
# such as mean, median, standard deviation, percentile, maximum and minimum value etc.to know it's distrubtion.

# %% [markdown]
# # identify the Attributes the data contains

# %%
df.columns.tolist()
# Out:
# ['Bearer Id',
#  'Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
# ...

# %% [markdown]
# # generate statistical summary of the data

# %%
df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %% [markdown]
# # understand the meaning of each attribute

# %%
import pandas as pd

description = pd.read_excel("E:\\10xAccademy_Practice\\Week 1\\Data\\Field Descriptions.xlsx")
description
# Out:
#                                       Fields  \
# 0                                  bearer id
# 1                                  Dur. (ms)
# 2                                      Start
# 3                                   Start ms
# 4                                        End
# 5                                     End ms
# 6                                   Dur. (s)
# 7                                       IMSI
# 8                              MSISDN/Number
# 9                                       IMEI
# 10                        Last Location Name
# 11                           Avg RTT DL (ms)
# 12                           Avg RTT UL (ms)
# 13                   Avg Bearer TP DL (kbps)
# 14                   Avg Bearer TP UL (kbps)
# 15               TCP DL Retrans. Vol (Bytes)
# 16               TCP UL Retrans. Vol (Bytes)
# 17                       DL TP < 50 Kbps (%)
# 18            50 Kbps < DL TP < 250 Kbps (%)
# 19             250 Kbps < DL TP < 1 Mbps (%)
# ...

# %% [markdown]
# # understand the data type of each Attribute

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
duplicated_entries = df[df.duplicated()]
duplicated_entries.shape
# Out:
# (0, 55)

# %% [markdown]
# # Know Number of Missing and Duplicate Values

# %%
#number of missing values
missing=df.isnull()
missing
# Out:
#         Bearer Id  Start  Start ms    End  End ms  Dur. (ms)   IMSI  \
# 0           False  False     False  False   False      False  False
# 1           False  False     False  False   False      False  False
# 2           False  False     False  False   False      False  False
# 3           False  False     False  False   False      False  False
# 4           False  False     False  False   False      False  False
# ...           ...    ...       ...    ...     ...        ...    ...
# 149996      False  False     False  False   False      False  False
# 149997      False  False     False  False   False      False  False
# 149998      False  False     False  False   False      False  False
# 149999      False  False     False  False   False      False  False
# 150000       True   True      True   True    True       True   True
#
#         MSISDN/Number   IMEI  Last Location Name  ...  Youtube DL (Bytes)  \
# 0               False  False               False  ...               False
# ...

# %%
#Total number of missing values by column
total_missed=df.isnull().sum()
total_missed
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %%
#the total number of Missing values the data contains
total_missingValues=df.isnull().sum().sum()
print(f" The data contains {total_missingValues} missing values")
# Out:
#  The data contains 1031392 missing values

# %% [markdown]
# # calculate the percentage of missing values from the total dataset

# %%
#first calculate the percentage of missing values from the total data
def Percentage_Of_Missing(df):

    # Calculate total number of cells in dataframe
    #totalCells = np.product(df.shape)
    totalCells=df.shape[0]*df.shape[1] #column by row
    # Sum of Missing Values
    totalMissing_Value=df.isnull().sum().sum()
    percentage=round(((totalMissing_Value/totalCells) * 100), 2)

    print(f"There are {percentage} % Missing Values in the Total dataset")
Percentage_Of_Missing(df)
# Out:
# There are 12.5 % Missing Values in the Total dataset

# %% [markdown]
# # know the number of duplicate values

# %%
bool_series = df.duplicated()
bool_series
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149996    False
# 149997    False
# 149998    False
# 149999    False
# 150000    False
# Length: 150001, dtype: bool

# %%
TotalDuplicate_value=df.duplicated().sum().sum()
print(f"the dataset contains {TotalDuplicate_value} duplicate values")
# Out:
# the dataset contains 0 duplicate values

# %%
#extract Duplicated row
df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
df.shape
# Out:
# ()

# %%
#total size
df.size
# Out:
# 1

# %%
#from the above Plot we can understand that the dataset contains outliers, so, need to be handled using 
#different techniques.
def check_skewness(df):
        """Return the skewness of the dataset.

        Args:
            df (pd.DataFrame): a dataframe to be analyzed
        """
        # calculate skewness
        df = df.skew(axis=0, skipna=True)
        #print(skewness)
        return df
skew=check_skewness(df)
skew
# Out:
# C:\Users\HB\AppData\Local\Temp\ipykernel_11608\1072671474.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.skew(axis=0, skipna=True)
# Bearer Id                                     0.026666
# Start ms                                      0.000968
# End ms                                       -0.001163
# Dur. (ms)                                     3.952609
# IMSI                                         41.045956
# MSISDN/Number                               332.155856
# IMEI                                          1.071470
# Avg RTT DL (ms)                              62.907828
# Avg RTT UL (ms)                              28.457415
# Avg Bearer TP DL (kbps)                       2.589437
# Avg Bearer TP UL (kbps)                       4.503413
# ...

# %%
import sys

import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join('./')))
class Preprocess_Task:
    def __init__(self, df: pd.DataFrame):
        self.df = df
    def convert_to_datetime(self, df, column: str):

        df[column] = pd.to_datetime(
            df[column], errors='coerce')
        return df
    def convert_to_float(self, df, column: str):
        self.df[column] = df[column].astype(float)
        return self.df
    def drop_variables(self, df):
        df_before_filling = df.copy()
        df = df[df.columns[df.isnull().mean() < 0.3]]
        missing_cols = df.columns[df.isnull().mean() > 0]
        print(missing_cols)
        return df, df_before_filling, missing_cols
    def clean_feature_name(self, df):
        df.columns = [column.replace(' ', '_').lower()
                      for column in df.columns]
        return df
    def rename_columns(self, df: pd.DataFrame, column: str, new_column: str):
        df[column] = df[column].rename(new_column)
        dfRenamed = df.rename({column: new_column}, axis=1)
        return dfRenamed
    def fill_numerical_variables(self, df):
        df_single = df
        cols = df_single.columns
        num_cols = df_single.select_dtypes(include=np.number).columns
        df_single.loc[:, num_cols] = df_single.loc[:, num_cols].fillna(
            df_single.loc[:, num_cols].median())
        print(num_cols)
        print(df_single.loc[:, num_cols].median())
        return cols, df_single, num_cols
    def fill_categorical_variables(self, df, cols, num_cols, df_single):

        cat_cols = list(set(cols) - set(num_cols))
        df_single.loc[:, cat_cols] = df_single.loc[:, cat_cols].fillna(
            df.loc[:, cat_cols].mode().iloc[0])
        df_cols = df_single.columns
        print(cat_cols)
        print(df_single.loc[:, cat_cols].mode().iloc[0])
        return df_cols, df_single, cat_cols

    def drop_duplicates(self, df):
        df = df.drop_duplicates()
        return df
    def convert_bytes_to_megabytes(self, df, col):

        megabyte = 1*10e+5
        megabyte_col = df[col] / megabyte
        return megabyte_col

# %%
preprocess=Preprocess_Task(df)
df = preprocess.clean_feature_name(df)
df.head(10)
# Out:
#       bearer_id            start  start_ms              end  end_ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5  1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6  1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7  1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8  1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9  1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
#
#    dur._(ms)          imsi  msisdn/number          imei  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = preprocess.drop_duplicates(df)
df.shape
# Out:
# (150001, 55)

# %%
df_c, df_before_filling, missing_cols = preprocess.drop_variables(df)
# Out:
# Index(['bearer_id', 'start', 'start_ms', 'end', 'end_ms', 'dur._(ms)', 'imsi',
#        'msisdn/number', 'imei', 'last_location_name', 'avg_rtt_dl_(ms)',
#        'avg_rtt_ul_(ms)', 'avg_bearer_tp_dl_(kbps)', 'avg_bearer_tp_ul_(kbps)',
#        'dl_tp_<_50_kbps_(%)', '50_kbps_<_dl_tp_<_250_kbps_(%)',
#        '250_kbps_<_dl_tp_<_1_mbps_(%)', 'dl_tp_>_1_mbps_(%)',
#        'ul_tp_<_10_kbps_(%)', '10_kbps_<_ul_tp_<_50_kbps_(%)',
#        '50_kbps_<_ul_tp_<_300_kbps_(%)', 'ul_tp_>_300_kbps_(%)',
#        'activity_duration_dl_(ms)', 'activity_duration_ul_(ms)', 'dur._(ms).1',
#        'handset_manufacturer', 'handset_type', 'nb_of_sec_with_vol_dl_<_6250b',
#        'nb_of_sec_with_vol_ul_<_1250b', 'total_ul_(bytes)',
#        'total_dl_(bytes)'],
#       dtype='object')

# %%
cols, df_single, num_cols = preprocess.fill_numerical_variables(df)
df_single.head(10)
# Out:
# Index(['bearer_id', 'start_ms', 'end_ms', 'dur._(ms)', 'imsi', 'msisdn/number',
#        'imei', 'avg_rtt_dl_(ms)', 'avg_rtt_ul_(ms)', 'avg_bearer_tp_dl_(kbps)',
#        'avg_bearer_tp_ul_(kbps)', 'tcp_dl_retrans._vol_(bytes)',
#        'tcp_ul_retrans._vol_(bytes)', 'dl_tp_<_50_kbps_(%)',
#        '50_kbps_<_dl_tp_<_250_kbps_(%)', '250_kbps_<_dl_tp_<_1_mbps_(%)',
#        'dl_tp_>_1_mbps_(%)', 'ul_tp_<_10_kbps_(%)',
#        '10_kbps_<_ul_tp_<_50_kbps_(%)', '50_kbps_<_ul_tp_<_300_kbps_(%)',
#        'ul_tp_>_300_kbps_(%)', 'http_dl_(bytes)', 'http_ul_(bytes)',
#        'activity_duration_dl_(ms)', 'activity_duration_ul_(ms)', 'dur._(ms).1',
#        'nb_of_sec_with_125000b_<_vol_dl',
#        'nb_of_sec_with_1250b_<_vol_ul_<_6250b',
#        'nb_of_sec_with_31250b_<_vol_dl_<_125000b',
#        'nb_of_sec_with_37500b_<_vol_ul',
#        'nb_of_sec_with_6250b_<_vol_dl_<_31250b',
#        'nb_of_sec_with_6250b_<_vol_ul_<_37500b',
# ...

# %%
#check missing values in a column
df_single.isnull().sum()
#df.info()
# Out:
# bearer_id                                   0
# start                                       0
# start_ms                                    0
# end                                         0
# end_ms                                      0
# dur._(ms)                                   0
# imsi                                        0
# msisdn/number                               0
# imei                                        0
# last_location_name                          0
# avg_rtt_dl_(ms)                             0
# avg_rtt_ul_(ms)                             0
# avg_bearer_tp_dl_(kbps)                     0
# avg_bearer_tp_ul_(kbps)                     0
# tcp_dl_retrans._vol_(bytes)                 0
# tcp_ul_retrans._vol_(bytes)                 0
# dl_tp_<_50_kbps_(%)                         0
# 50_kbps_<_dl_tp_<_250_kbps_(%)              0
# 250_kbps_<_dl_tp_<_1_mbps_(%)               0
# dl_tp_>_1_mbps_(%)                          0
# ...

# %%
df_single.isna().sum().nlargest(10)
# Out:
# bearer_id             0
# start                 0
# start_ms              0
# end                   0
# end_ms                0
# dur._(ms)             0
# imsi                  0
# msisdn/number         0
# imei                  0
# last_location_name    0
# dtype: int64

# %%
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   bearer_id                                 150001 non-null  float64
#  1   start                                     150001 non-null  object
#  2   start_ms                                  150001 non-null  float64
#  3   end                                       150001 non-null  object
#  4   end_ms                                    150001 non-null  float64
#  5   dur._(ms)                                 150001 non-null  float64
#  6   imsi                                      150001 non-null  float64
#  7   msisdn/number                             150001 non-null  float64
#  8   imei                                      150001 non-null  float64
#  9   last_location_name                        150001 non-null  object
# ...

# %%
df["social_media"] = df["social_media_dl_(bytes)"] + df['social_media_ul_(bytes)']
df["google"] = df["google_dl_(bytes)"] + df["google_ul_(bytes)"]
df['email'] = df["email_dl_(bytes)"] + df["email_ul_(bytes)"]
df['youtube'] = df["youtube_dl_(bytes)"] + df["youtube_ul_(bytes)"]
df['netflix'] = df["netflix_dl_(bytes)"] + df["netflix_ul_(bytes)"]
df["gaming"] = df["gaming_dl_(bytes)"] + df["gaming_ul_(bytes)"]
df['other'] = df["other_dl_(bytes)"]+df["other_ul_(bytes)"]
df['total_data'] = df['total_dl_(bytes)'] + df['total_ul_(bytes)']

# %%
df['social_media'] = preprocess.convert_bytes_to_megabytes(df, 'social_media')
df['google'] = preprocess.convert_bytes_to_megabytes(df, 'google')
df['email'] = preprocess.convert_bytes_to_megabytes(df, 'email')
df['youtube'] = preprocess.convert_bytes_to_megabytes(df, 'youtube')
df['netflix'] = preprocess.convert_bytes_to_megabytes(df, 'netflix')
df['gaming'] = preprocess.convert_bytes_to_megabytes(df, 'gaming')
df['total_data'] = preprocess.convert_bytes_to_megabytes(df, 'total_data')
df['other'] = preprocess.convert_bytes_to_megabytes(df, 'other')

# %% [markdown]
# # Save Preprocessed Data

# %%
df.to_csv('E:\\10xAccademy_Practice\\Week 1\\Data\\Preprocessed_TelecomData.csv', index=False)

# %%
df_cols, df_single, cat_cols = preprocess.fill_categorical_variables(df, cols, num_cols, df_single)
# Out:
# ['last_location_name', 'end', 'start', 'handset_manufacturer', 'handset_type']
# last_location_name               D41377B
# end                       4/25/2019 0:01
# start                     4/26/2019 7:25
# handset_manufacturer               Apple
# handset_type            Huawei B528S-23A
# Name: 0, dtype: object

# %%
df.to_csv('E:\\10xAccademy_Practice\\Week 1\\Data\\Preprocessed_TelecomData.csv', index=False)

# %% [markdown]
# # Detecting outliers

# %%
# Out:
# array([[<AxesSubplot:title={'center':'bearer_id'}>,
#         <AxesSubplot:title={'center':'start_ms'}>,
#         <AxesSubplot:title={'center':'end_ms'}>,
#         <AxesSubplot:title={'center':'dur._(ms)'}>,
#         <AxesSubplot:title={'center':'imsi'}>,
#         <AxesSubplot:title={'center':'msisdn/number'}>,
#         <AxesSubplot:title={'center':'imei'}>,
#         <AxesSubplot:title={'center':'avg_rtt_dl_(ms)'}>],
#        [<AxesSubplot:title={'center':'avg_rtt_ul_(ms)'}>,
#         <AxesSubplot:title={'center':'avg_bearer_tp_dl_(kbps)'}>,
#         <AxesSubplot:title={'center':'avg_bearer_tp_ul_(kbps)'}>,
#         <AxesSubplot:title={'center':'tcp_dl_retrans._vol_(bytes)'}>,
#         <AxesSubplot:title={'center':'tcp_ul_retrans._vol_(bytes)'}>,
#         <AxesSubplot:title={'center':'dl_tp_<_50_kbps_(%)'}>,
#         <AxesSubplot:title={'center':'50_kbps_<_dl_tp_<_250_kbps_(%)'}>,
#         <AxesSubplot:title={'center':'250_kbps_<_dl_tp_<_1_mbps_(%)'}>],
# ...

# %%
# Out:
# C:\Users\HB\AppData\Local\Temp\ipykernel_11608\2371750961.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   skew=df = df2.skew(axis=0, skipna=True)
# bearer_id                                     0.039699
# start_ms                                      0.000968
# end_ms                                       -0.001163
# dur._(ms)                                     3.952624
# imsi                                         41.124210
# msisdn/number                               333.342445
# imei                                          1.077346
# avg_rtt_dl_(ms)                              69.557811
# avg_rtt_ul_(ms)                              31.426589
# avg_bearer_tp_dl_(kbps)                       2.589447
# avg_bearer_tp_ul_(kbps)                       4.503429
# ...

# %%
#we can use different methods to detect the presence of outliers in the data.
# one method is Boxplot, Scatterplot, Z-score, Inter-Quartile range
import seaborn as sns
sns.boxplot(df['IMSI'])
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IMSI'>

# %%
#Check the skewness of the data using histogram plot
df.hist(bins=80, figsize=(30,25))
# Out:
# array([[<AxesSubplot:title={'center':'Bearer Id'}>,
#         <AxesSubplot:title={'center':'Start ms'}>,
#         <AxesSubplot:title={'center':'End ms'}>,
#         <AxesSubplot:title={'center':'Dur. (ms)'}>,
#         <AxesSubplot:title={'center':'IMSI'}>,
#         <AxesSubplot:title={'center':'MSISDN/Number'}>,
#         <AxesSubplot:title={'center':'IMEI'}>],
#        [<AxesSubplot:title={'center':'Avg RTT DL (ms)'}>,
#         <AxesSubplot:title={'center':'Avg RTT UL (ms)'}>,
#         <AxesSubplot:title={'center':'Avg Bearer TP DL (kbps)'}>,
#         <AxesSubplot:title={'center':'Avg Bearer TP UL (kbps)'}>,
#         <AxesSubplot:title={'center':'TCP DL Retrans. Vol (Bytes)'}>,
#         <AxesSubplot:title={'center':'TCP UL Retrans. Vol (Bytes)'}>,
#         <AxesSubplot:title={'center':'DL TP < 50 Kbps (%)'}>],
#        [<AxesSubplot:title={'center':'50 Kbps < DL TP < 250 Kbps (%)'}>,
#         <AxesSubplot:title={'center':'250 Kbps < DL TP < 1 Mbps (%)'}>,
# ...

# %%
import sys

import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join('./')))
class Preprocess_Task:
    def __init__(self, df: pd.DataFrame):
        self.df = df
    def convert_to_datetime(self, df, column: str):

        df[column] = pd.to_datetime(
            df[column], errors='coerce')
        return df
    def convert_to_float(self, df, column: str):
        self.df[column] = df[column].astype(float)
        return self.df
    def drop_variables(self, df):
        df_before_filling = df.copy()
        df = df[df.columns[df.isnull().mean() < 0.3]]
        missing_cols = df.columns[df.isnull().mean() > 0]
        print(missing_cols)
        return df, df_before_filling, missing_cols
    def clean_feature_name(self, df):
        df.columns = [column.replace(' ', '_').lower()
                      for column in df.columns]
        return df
    def rename_columns(self, df: pd.DataFrame, column: str, new_column: str):
        df[column] = df[column].rename(new_column)
        dfRenamed = df.rename({column: new_column}, axis=1)
        return dfRenamed
    def fill_numerical_variables(self, df):
        df_single = df
        cols = df_single.columns
        num_cols = df_single.select_dtypes(include=np.number).columns
        df_single.loc[:, num_cols] = df_single.loc[:, num_cols].fillna(
            df_single.loc[:, num_cols].median())
        print(num_cols)
        print(df_single.loc[:, num_cols].median())
        return cols, df_single, num_cols
    def fill_categorical_variables(self, df, cols, num_cols, df_single):

        cat_cols = list(set(cols) - set(num_cols))
        df_single.loc[:, cat_cols] = df_single.loc[:, cat_cols].fillna(
            df.loc[:, cat_cols].mode().iloc[0])
        df_cols = df_single.columns
        print(cat_cols)
        print(df_single.loc[:, cat_cols].mode().iloc[0])
        return df_cols, df_single, cat_cols

    def drop_duplicates(self, df):
        df = df.drop_duplicates()
        return df
    def convert_bytes_to_megabytes(self, df, col):

        megabyte = 1*10e+5
        megabyte_col = df[col] / megabyte
        return megabyte_col

# %%
 def drop_duplicates(df):
        """Drop duplicates.

        Args:
            df (pd.DataFrame): A dataframe to be preprocessed
        """
        df = df.drop_duplicates()

        return df
df=drop_duplicates(df)
df
# Out:
# Bearer Id                                     0.026666
# Start ms                                      0.000968
# End ms                                       -0.001163
# Dur. (ms)                                     3.952609
# IMSI                                         41.045956
# MSISDN/Number                               332.155856
# IMEI                                          1.071470
# Avg RTT DL (ms)                              62.907828
# Avg RTT UL (ms)                              28.457415
# Avg Bearer TP DL (kbps)                       2.589437
# Avg Bearer TP UL (kbps)                       4.503413
# TCP DL Retrans. Vol (Bytes)                  15.951809
# TCP UL Retrans. Vol (Bytes)                  84.113393
# DL TP < 50 Kbps (%)                          -2.297803
# 50 Kbps < DL TP < 250 Kbps (%)                3.271453
# 250 Kbps < DL TP < 1 Mbps (%)                 4.566158
# DL TP > 1 Mbps (%)                            5.370351
# ...

# %%
prep=Preprocess_Task(df)
prep

df=drop_duplicates(df)
df
# Out:
# Bearer Id                                     0.026666
# Start ms                                      0.000968
# End ms                                       -0.001163
# Dur. (ms)                                     3.952609
# IMSI                                         41.045956
# MSISDN/Number                               332.155856
# IMEI                                          1.071470
# Avg RTT DL (ms)                              62.907828
# Avg RTT UL (ms)                              28.457415
# Avg Bearer TP DL (kbps)                       2.589437
# Avg Bearer TP UL (kbps)                       4.503413
# TCP DL Retrans. Vol (Bytes)                  15.951809
# TCP UL Retrans. Vol (Bytes)                  84.113393
# DL TP < 50 Kbps (%)                          -2.297803
# 50 Kbps < DL TP < 250 Kbps (%)                3.271453
# 250 Kbps < DL TP < 1 Mbps (%)                 4.566158
# DL TP > 1 Mbps (%)                            5.370351
# ...

# %% [markdown]
# # save preprocessed data

# %%
df.to_csv('E:\\10xAccademy_Practice\\Week 1\\Data\\Preprocessed_TelecomData.csv', index=False)

# %%
import seaborn as sns
sns.boxplot(df['Avg Bearer TP DL (kbps)'])
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Avg Bearer TP DL (kbps)'>

# %%
sns.boxplot(df['Avg Bearer TP DL (kbps)'])
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='50 Kbps < DL TP < 250 Kbps (%)'>

# %%
sns.boxplot(df['DL TP > 1 Mbps (%)'])
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DL TP > 1 Mbps (%)'>

# %%
# Scatter plot
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['50 Kbps < DL TP < 250 Kbps (%)'], df['HTTP DL (Bytes)'])
 
# x-axis label
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
 
# y-axis label
ax.set_ylabel('(Full-value property-tax rate)/( $10,000)')
plt.show()

# %%
#Remove Outliers using standard deviation
def remove_outliers(df,columns,n_std):
    for col in columns:
        print('Working on column: {}'.format(col))
        mean = df[col].mean()
        sd = df[col].std()
        print(sd)
        df = df[(df[col] <= mean+(n_std*sd))]
        print(df)   
    return df
remove_outliers(df,df.columns,2)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Nb of sec with 1250B < Vol UL < 6250B'])
plt.subplot(1,2,2)
sns.distplot(df['Nb of sec with Vol UL < 1250B'])
plt.show()



plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['IMSI'])
plt.subplot(1,2,2)
sns.distplot(df['Avg RTT DL (ms)'])
plt.show()

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Google DL (Bytes)'])
plt.subplot(1,2,2)
sns.distplot(df['Email UL (Bytes)'])
plt.show()
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
percentile25 = df['Avg RTT UL (ms)'].quantile(0.25)
percentile75 = df['Avg RTT UL (ms)'].quantile(0.75)
iqr=percentile75-percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

df[df['Avg RTT UL (ms)'] > upper_limit]
df[df['Avg RTT UL (ms)'] < lower_limit]
print(f"lower limit : {lower_limit} and upper limit {upper_limit}" )
new_df = df[df['Avg RTT UL (ms)'] < upper_limit]
new_df.shape
new_df
#df['Avg RTT UL (ms)']
# Out:
# lower limit : -17.5 and upper limit 34.5
# 0          5.0
# 1          5.0
# 6          5.0
# 7         18.0
# 9          7.0
#           ...
# 149995     9.0
# 149996     0.0
# 149997     2.0
# 149998     6.0
# 149999     5.0
# Name: Avg RTT UL (ms), Length: 110946, dtype: float64

# %%
df['Avg RTT UL (ms)'] = np.where(df['Avg RTT UL (ms)'] >= upper_limit,
        upper_limit,
        np.where(df['Avg RTT UL (ms)'] <= lower_limit,
        lower_limit,
        df['Avg RTT UL (ms)']))

# %%
sns.distplot(df['Avg RTT UL (ms)'])
sns.boxplot(df['Avg RTT UL (ms)'])
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Avg RTT UL (ms)', ylabel='Density'>

# %%
sns.distplot(new_df['Avg RTT UL (ms)'])
sns.boxplot(new_df['Avg RTT UL (ms)'])
# Out:
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hb\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Avg RTT UL (ms)', ylabel='Density'>

# %%
df.hist(bins=80, figsize=(30,25))
# Out:
# array([[<AxesSubplot:title={'center':'Bearer Id'}>,
#         <AxesSubplot:title={'center':'Start ms'}>,
#         <AxesSubplot:title={'center':'End ms'}>,
#         <AxesSubplot:title={'center':'Dur. (ms)'}>,
#         <AxesSubplot:title={'center':'IMSI'}>,
#         <AxesSubplot:title={'center':'MSISDN/Number'}>,
#         <AxesSubplot:title={'center':'IMEI'}>],
#        [<AxesSubplot:title={'center':'Avg RTT DL (ms)'}>,
#         <AxesSubplot:title={'center':'Avg RTT UL (ms)'}>,
#         <AxesSubplot:title={'center':'Avg Bearer TP DL (kbps)'}>,
#         <AxesSubplot:title={'center':'Avg Bearer TP UL (kbps)'}>,
#         <AxesSubplot:title={'center':'TCP DL Retrans. Vol (Bytes)'}>,
#         <AxesSubplot:title={'center':'TCP UL Retrans. Vol (Bytes)'}>,
#         <AxesSubplot:title={'center':'DL TP < 50 Kbps (%)'}>],
#        [<AxesSubplot:title={'center':'50 Kbps < DL TP < 250 Kbps (%)'}>,
#         <AxesSubplot:title={'center':'250 Kbps < DL TP < 1 Mbps (%)'}>,
# ...

# %%
#Data Type
df.dtypes
# Out:
# Bearer Id                                   float64
# Start                                        object
# Start ms                                    float64
# End                                          object
# End ms                                      float64
# Dur. (ms)                                   float64
# IMSI                                        float64
# MSISDN/Number                               float64
# IMEI                                        float64
# Last Location Name                           object
# Avg RTT DL (ms)                             float64
# Avg RTT UL (ms)                             float64
# Avg Bearer TP DL (kbps)                     float64
# Avg Bearer TP UL (kbps)                     float64
# TCP DL Retrans. Vol (Bytes)                 float64
# TCP UL Retrans. Vol (Bytes)                 float64
# DL TP < 50 Kbps (%)                         float64
# 50 Kbps < DL TP < 250 Kbps (%)              float64
# ...

# %%
# Null Value of Each Column
df.isnull().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %%
df.isnull().sum().sum()
# Out:
# 1031392

# %%
# Handset Type with Frequency Count of Items
df1=df['Handset Type'].value_counts(dropna=False).sort_values(ascending = False)
# Top 10 Handset Types
df1.head(10)
# Out:
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: Handset Type, dtype: int64

# %%
# Handset Manufacturers with Frequency Count of Items
df2=df['Handset Manufacturer'].value_counts(dropna=False).sort_values(ascending = False)
#top 3 Handset manufacturesrs
df2.head(3)
# Out:
# 171

# %%
info_df = pd.concat([df["Handset Manufacturer"], df["Handset Type"]], axis=1)
info_df.head(20)
# Out:
#    Handset Manufacturer                         Handset Type
# 0               Samsung           Samsung Galaxy A5 Sm-A520F
# 1               Samsung          Samsung Galaxy J5 (Sm-J530)
# 2               Samsung             Samsung Galaxy A8 (2018)
# 3             undefined                            undefined
# 4               Samsung                     Samsung Sm-G390F
# 5             undefined                            undefined
# 6                Huawei                  Huawei Mate 20 Lite
# 7             undefined                            undefined
# 8               Samsung             Samsung Galaxy A8 (2018)
# 9               Samsung  Samsung Galaxy Note 8 (Sm-N950F Ds)
# 10            undefined                            undefined
# 11               Huawei                      Huawei B593S-22
# 12              Samsung           Samsung Galaxy A5 Sm-A520F
# 13              Samsung  Samsung Galaxy Note 8 (Sm-N950F Ds)
# ...

# %%
# Total Unique value count of each column
pd.DataFrame(df.apply(lambda x: len(x.value_counts(dropna=False)), axis=0), columns=['Unique Value Count']).sort_values(by='Unique Value Count', ascending=True)
# Out:
#                                           Unique Value Count
# UL TP > 300 Kbps (%)                                      64
# 50 Kbps < UL TP < 300 Kbps (%)                            69
# 250 Kbps < DL TP < 1 Mbps (%)                             74
# 50 Kbps < DL TP < 250 Kbps (%)                            85
# 10 Kbps < UL TP < 50 Kbps (%)                             86
# DL TP > 1 Mbps (%)                                        86
# UL TP < 10 Kbps (%)                                       99
# DL TP < 50 Kbps (%)                                      101
# Handset Manufacturer                                     171
# Avg RTT UL (ms)                                          723
# Start ms                                                1001
# End ms                                                  1001
# Nb of sec with 37500B < Vol UL                          1105
# Handset Type                                            1397
# ...

# %%
df1=pd.Series(df['Handset Manufacturer'].unique()).sort_values(ascending=False)
print(str(df1))
# Out:
# 1                                    undefined
# 127                  Zyxel Communications Corp
# 163                  ZyXEL Communications Corp
# 4                                          Zte
# 11                    Zebra Technologies Corp.
#                         ...
# 128                                       Adar
# 64                                        Acer
# 68                                     ASUSTeK
# 105    A-Link Telecom International Co Limited
# 10                                         NaN
# Length: 171, dtype: object

# %%
# Manufacturers with Frequency Count of Items
df1=df['Handset Manufacturer'].value_counts(dropna=False).sort_values(ascending = False)
df1.head(10)
# Out:
# Apple                                   59565
# Samsung                                 40839
# Huawei                                  34423
# undefined                                8987
# Sony Mobile Communications Ab             980
# Wiko Global Sasu                          747
# NaN                                       572
# Xiaomi Communications Co Ltd              397
# Oneplus Technology (Shenzhen) Co Ltd      342
# Asustek                                   285
# Name: Handset Manufacturer, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
df.columns.tolist()
# Out:
# ['Bearer Id',
#  'Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
# ...

# %%
print(f" There Are {df.shape[0]} Rows and {df.shape[1]} columns")
# Out:
#  There Are 150001 Rows and 55 columns

# %%
df.isnull()
# Out:
#         Bearer Id  Start  Start ms    End  End ms  Dur. (ms)   IMSI  \
# 0           False  False     False  False   False      False  False
# 1           False  False     False  False   False      False  False
# 2           False  False     False  False   False      False  False
# 3           False  False     False  False   False      False  False
# 4           False  False     False  False   False      False  False
# ...           ...    ...       ...    ...     ...        ...    ...
# 149996      False  False     False  False   False      False  False
# 149997      False  False     False  False   False      False  False
# 149998      False  False     False  False   False      False  False
# 149999      False  False     False  False   False      False  False
# 150000       True   True      True   True    True       True   True
#
#         MSISDN/Number   IMEI  Last Location Name  ...  Youtube DL (Bytes)  \
# 0               False  False               False  ...               False
# ...

# %%
#Number of Missing values in particular column
df["Handset Type"].isnull().sum().sum()
# Out:
# 572

# %%
sorted=df.sort_values(by=["Handset Type"])
sorted
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 22915   1.304243e+19  4/24/2019 20:40     420.0   4/25/2019 0:01   627.0
# 24538   6.917538e+18  4/24/2019 20:59     908.0   4/25/2019 1:58   147.0
# 83394   6.917538e+18  4/27/2019 10:27     402.0   4/28/2019 0:34   169.0
# 98614   1.304243e+19  4/27/2019 17:10     126.0   4/28/2019 1:36   683.0
# 24450   1.304243e+19  4/24/2019 20:58     423.0   4/25/2019 0:01    89.0
# ...              ...              ...       ...              ...     ...
# 149058           NaN   4/29/2019 7:18     358.0   4/30/2019 0:11   376.0
# 149206           NaN   4/29/2019 7:20     182.0   4/30/2019 0:24   834.0
# 149375           NaN   4/29/2019 7:22      57.0  4/29/2019 23:12   744.0
# 149723           NaN   4/29/2019 7:26     375.0   4/30/2019 6:26   784.0
# 150000           NaN              NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
larger=len(df["Handset Type"])
larger
# Out:
# 150001

# %%
handset_type=df["Handset Type"].value_counts()
print("       Top Ten Handset Types Are:  \n")
handset_type.head(10)
# Out:
#        Top Ten Handset Types Are:
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: Handset Type, dtype: int64

# %%
handset_Manufacturer=df["Handset Manufacturer"].value_counts()
print("           Top Ten Handset Manufacturers are: \n")
handset_Manufacturer.head(10)
# Out:
#            Top Ten Handset Manufacturers are:
# Apple                                   59565
# Samsung                                 40839
# Huawei                                  34423
# undefined                                8987
# Sony Mobile Communications Ab             980
# Wiko Global Sasu                          747
# Xiaomi Communications Co Ltd              397
# Oneplus Technology (Shenzhen) Co Ltd      342
# Asustek                                   285
# Lenovo                                    254
# Name: Handset Manufacturer, dtype: int64

# %%
df["Handset Manufacturer"].value_counts().max
df["Handset Manufacturer"].value_counts().max

print("manufacturers are:\n",df["Handset Manufacturer"].value_counts().max)
# Out:
# manufacturers are:
#  <bound method NDFrame._add_numeric_operations.<locals>.max of Apple                               59565
# Samsung                             40839
# Huawei                              34423
# undefined                            8987
# Sony Mobile Communications Ab         980
#                                     ...
# Pt. Arga Mas Lestari                    1
# Doke Communication (Hk) Limited         1
# Vastking Technology (Hk) Limited        1
# Mobiwire Sas                            1
# Shenzhen Gaoxinqi                       1
# Name: Handset Manufacturer, Length: 170, dtype: int64>

# %%
df.value_counts(dropna=True)
df.head(10)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5  1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6  1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7  1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8  1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9  1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# ...

# %%
df["Handset Type"].unique()
# Out:
# array(['Samsung Galaxy A5 Sm-A520F', 'Samsung Galaxy J5 (Sm-J530)',
#        'Samsung Galaxy A8 (2018)', ..., 'Asustek Asus Zb500Kg',
#        'Huawei Mediapad T5 10 Pro',
#        'Shenzhen Jeko Co. Blackview Bv5800 Pro'], dtype=object)

# %%
#df = df.groupby('Handset Type').count()
df.groupby('Handset Type').count()
# Out:
#                                                     Bearer Id  Start  \
# Handset Type
# A-Link Telecom I. Cubot A5                                  1      1
# A-Link Telecom I. Cubot Note Plus                           1      1
# A-Link Telecom I. Cubot Note S                              1      1
# A-Link Telecom I. Cubot Nova                                1      1
# A-Link Telecom I. Cubot Power                               1      1
# ...                                                       ...    ...
# Zte Zte Blade C2 Smartphone Android By Sfr Star...          2      2
# Zyxel Communicat. Lte7460                                   1      1
# Zyxel Communicat. Sbg3600                                   1      1
# Zyxel Communicat. Zyxel Wah7706                             1      1
# undefined                                                8960   8987
#
#                                                     Start ms   End  End ms  \
# Handset Type
# ...

# %%
df["Handset Type"].unique()
#df.groupby('Handset Type').sum()
# Out:
# array(['Samsung Galaxy A5 Sm-A520F', 'Samsung Galaxy J5 (Sm-J530)',
#        'Samsung Galaxy A8 (2018)', ..., 'Asustek Asus Zb500Kg',
#        'Huawei Mediapad T5 10 Pro',
#        'Shenzhen Jeko Co. Blackview Bv5800 Pro'], dtype=object)

# %% [markdown]
# # Handle Missing Data

# %%
#first calculate the percentage of missing values from the total data
import numpy as np
def Percentage_Of_Missing(df):

    # Calculate total number of cells in dataframe
    totalCells = np.product(df.shape)
    # Sum of Missing Values
    totalMissing_Value=df.isnull().sum().sum()
    percentage=round(((totalMissing_Value/totalCells) * 100), 2)

    print(f"There are {percentage} % Missing Values in the dataset")
Percentage_Of_Missing(df)
# Out:
# There are 12.5 % Missing Values in the dataset

# %%
df1=df.groupby('Handset Type')
df1.head()
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149488  1.304243e+19   4/29/2019 7:23     421.0   4/30/2019 7:23   395.0
# 149598  6.917538e+18   4/29/2019 7:24     750.0   4/30/2019 7:24   375.0
# 149605  6.917538e+18   4/29/2019 7:24     632.0   4/30/2019 7:01   120.0
# 149743  6.917538e+18   4/29/2019 7:26     679.0   4/30/2019 7:16   474.0
# 149860  6.917538e+18   4/29/2019 7:27     328.0   4/30/2019 7:29   168.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
df.groupby('Handset Type').agg(['min', 'max'])
df
# Out:
# C:\Users\HB\AppData\Local\Temp\ipykernel_22684\2369330607.py:1: FutureWarning: ['Last Location Name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('Handset Type').agg(['min', 'max'])
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# ...

# %%
df.groupby('Handset Type').Handset Manufacturer.agg(['min', 'max'])
# Out:
#   Input In [75]
#     df.groupby('Handset Type').Handset Manufacturer.agg(['min', 'max'])
#                                        ^
# SyntaxError: invalid syntax

# %%
df.groupby('Handset Type')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df.groupby('Handset Type')
#
# NameError: name 'df' is not defined
